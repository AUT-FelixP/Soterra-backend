# %% [markdown]
# # Inspection OCR Benchmark
#
# This notebook benchmarks five local extraction stacks against the Kauri inspection PDFs and writes a Notion-ready report.

# %%
import sys
from pathlib import Path

candidates = [Path.cwd().resolve(), Path.cwd().resolve().parent]
for candidate in candidates:
    if str(candidate) not in sys.path:
        sys.path.append(str(candidate))

from notebooks.inspection_benchmark import run_benchmark, build_notion_report

# %%
summary_df, detail_df = run_benchmark()
summary_df

# %%
detail_df[[
    'engine',
    'document',
    'runtime_seconds',
    'text_chars',
    'field_completion',
    'keyword_coverage',
    'finding_candidates',
    'schema_pass',
    'project_name',
    'inspection_date',
    'inspection_type',
]]

# %%
report_md = build_notion_report(summary_df, detail_df)
print(report_md)
