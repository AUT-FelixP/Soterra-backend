# %% [markdown]
# # Inspection Pipeline Benchmark
#
# This notebook measures full pipelines: extraction, schema validation, and PII redaction.

# %%
import sys
from pathlib import Path

candidates = [Path.cwd().resolve(), Path.cwd().resolve().parent]
for candidate in candidates:
    if str(candidate) not in sys.path:
        sys.path.append(str(candidate))

from notebooks.inspection_pipeline_benchmark import run_benchmark, build_notion_report

# %%
summary_df, detail_df = run_benchmark()
summary_df

# %%
detail_df

# %%
report_md = build_notion_report(summary_df, detail_df)
print(report_md)
